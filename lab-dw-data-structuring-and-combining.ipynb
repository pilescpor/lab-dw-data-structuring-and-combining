# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

url1 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv"
df1 = pd.read_csv(url1)

url2 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv"
df2 = pd.read_csv(url2)

url3 = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv"
df3 = pd.read_csv(url3)

# %%
# %reload_ext autoreload
# %autoreload 2
from Funtions import clean_columns_names
from Funtions import fix_invalid_values
from Funtions import format_data_types
from Funtions import drop_null
from Funtions import drop_duplicates

# %%
df1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
df2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
df3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
clean_columns_names(df1)
clean_columns_names(df2)
clean_columns_names(df3)

# %%
unido = pd.concat([df1, df2, df3], axis=0)
unido.head()
# Out:
#   customer customer_lifetime_value             education gender   income  \
# 0  RB50392                     NaN                Master    NaN      0.0
# 1  QZ44356              697953.59%              Bachelor      F      0.0
# 2  AI49188             1288743.17%              Bachelor      F  48767.0
# 3  WW63253              764586.18%              Bachelor      M      0.0
# 4  GA49547              536307.65%  High School or Below      M  36357.0
#
#    monthly_premium_auto number_of_open_complaints     policy_type       state  \
# 0                1000.0                    1/0/00   Personal Auto  Washington
# 1                  94.0                    1/0/00   Personal Auto     Arizona
# 2                 108.0                    1/0/00   Personal Auto      Nevada
# 3                 106.0                    1/0/00  Corporate Auto  California
# 4                  68.0                    1/0/00   Personal Auto  Washington
#
#    total_claim_amount  vehicle_class
# ...

# %%
fix_invalid_values(unido)
format_data_types(unido)
drop_null(unido)
drop_duplicates(unido)
unido
# Out:
#       index customer  customer_lifetime_value             education gender  \
# 0         1  QZ44356                697953.59              Bachelor      F
# 1         2  AI49188               1288743.17              Bachelor      F
# 2         3  WW63253                764586.18              Bachelor      M
# 3         4  GA49547                536307.65  High School or Below      M
# 4         5  OC83172                825629.78              Bachelor      F
# 5         6  XZ87318                538089.86               College      F
# 6         7  CF85061                721610.03                Master      M
# 7         8  DY87989               2412750.40              Bachelor      M
# 8         9  BQ94931                738817.81               College      F
# 9        10  SX51350                473899.20               College      M
# 10       21  QK46697                617710.93              Bachelor      M
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
url = "https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv"

df = pd.read_csv(url)

# %%
df.head()
# Out:
#    unnamed:_0 customer       state  customer_lifetime_value response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    coverage education effective_to_date employmentstatus gender  ...   \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df.tail()
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...   \
# 10905   Premium  Bachelor        2011-01-19       Unemployed      F  ...
# 10906     Basic   College        2011-01-06         Employed      F  ...
# 10907  Extended  Bachelor        2011-02-06         Employed      F  ...
# 10908   Premium   College        2011-02-13         Employed      F  ...
# 10909     Basic  Bachelor        2011-01-08       Unemployed      M  ...
#
#        number_of_policies     policy_type        policy  renew_offer_type  \
# ...

# %%
df.columns
# Out:
# Index(['unnamed:_0', 'customer', 'state', 'customer_lifetime_value',
#        'response', 'coverage', 'education', 'effective_to_date',
#        'employmentstatus', 'gender', 'income', 'location_code',
#        'marital_status', 'monthly_premium_auto', 'months_since_last_claim',
#        'months_since_policy_inception', 'number_of_open_complaints',
#        'number_of_policies', 'policy_type', 'policy', 'renew_offer_type',
#        'sales_channel', 'total_claim_amount', 'vehicle_class', 'vehicle_size',
#        'vehicle_type', 'month'],
#       dtype='object')

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_df = df.pivot_table(columns='sales_channel', values=['total_claim_amount'], aggfunc='sum').round(2)
pivot_df
# Out:
# sales_channel            Agent     Branch  Call Center        Web
# total_claim_amount  1810226.82  1301204.0    926600.82  706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
new_df = df[["customer_lifetime_value", "gender", "education"]]
new_df
# Out:
#        customer_lifetime_value gender             education
# 0                  4809.216960      M               College
# 1                  2228.525238      F               College
# 2                 14947.917300      M              Bachelor
# 3                 22332.439460      M               College
# 4                  9025.067525      F              Bachelor
# 5                  4745.181764      M  High School or Below
# 6                  5035.035257      F                Doctor
# 7                  4956.247235      M  High School or Below
# 8                  5989.773931      M               College
# 9                 17114.328150      F                Master
# 10                 5154.764074      M  High School or Below
# 11                 2420.711888      M              Bachelor
# 12                19955.257130      F  High School or Below
# 13                 5454.587929      M                Master
# 14                12836.009510      M  High School or Below
# ...

# %%
pivot_new_df = df.pivot_table(index='gender', columns='education', values=['customer_lifetime_value'], aggfunc='mean').round(2)
pivot_new_df
# Out:
#           customer_lifetime_value                                         \
# education                Bachelor  College   Doctor High School or Below
# gender
# F                         7874.27  7748.82  7328.51              8675.22
# M                         7703.60  8052.46  7415.33              8149.69
#
#
# education   Master
# gender
# F          8157.05
# M          8168.83

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
df_bonus= df[["number_of_open_complaints", "month", "policy_type"]]

# %%
df_bonus
# Out:
#        number_of_open_complaints  month     policy_type
# 0                       0.000000      2  Corporate Auto
# 1                       0.000000      1   Personal Auto
# 2                       0.000000      2   Personal Auto
# 3                       0.000000      1  Corporate Auto
# 4                       0.384256      1   Personal Auto
# 5                       0.000000      2   Personal Auto
# 6                       3.000000      2  Corporate Auto
# 7                       0.000000      2   Personal Auto
# 8                       0.000000      1   Personal Auto
# 9                       0.000000      1  Corporate Auto
# 10                      0.000000      1  Corporate Auto
# 11                      0.000000      2  Corporate Auto
# 12                      0.000000      1  Corporate Auto
# 13                      0.000000      1   Personal Auto
# 14                      0.000000      2   Personal Auto
# 15                      0.000000      1    Special Auto
# ...

# %%
melted_data = pd.melt(df_bonus, id_vars=['month', 'policy_type'], value_vars=['number_of_open_complaints'], var_name='Indicator', value_name='Value')
melted_data
# Out:
#        month     policy_type                  Indicator     Value
# 0          2  Corporate Auto  number_of_open_complaints  0.000000
# 1          1   Personal Auto  number_of_open_complaints  0.000000
# 2          2   Personal Auto  number_of_open_complaints  0.000000
# 3          1  Corporate Auto  number_of_open_complaints  0.000000
# 4          1   Personal Auto  number_of_open_complaints  0.384256
# 5          2   Personal Auto  number_of_open_complaints  0.000000
# 6          2  Corporate Auto  number_of_open_complaints  3.000000
# 7          2   Personal Auto  number_of_open_complaints  0.000000
# 8          1   Personal Auto  number_of_open_complaints  0.000000
# 9          1  Corporate Auto  number_of_open_complaints  0.000000
# 10         1  Corporate Auto  number_of_open_complaints  0.000000
# 11         2  Corporate Auto  number_of_open_complaints  0.000000
# 12         1  Corporate Auto  number_of_open_complaints  0.000000
# ...
